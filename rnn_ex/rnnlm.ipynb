# %%
import numpy as np
import theano
import theano.tensor as T
import time
from itertools import chain

import lasagne as L

from SimpleRNNLM import SimpleRNNLM, iterate_minibatches
from mt_load import load_mt, get_mt_voc, get_w2v_embs
# Out:
# Using gpu device 0: GeForce GTX 970 (CNMeM is enabled with initial size: 30.0% of memory, cuDNN 5005)

# %%
# remember, now the pad value is the same as the <utt_end> token

pad_value = -1 # <utt_end>'s vector is the last one

# %%
mt_path = "/pio/data/data/mtriples/"
mt_path = "/home/maciek/Desktop/mgr/DATA/MovieTriples_Dataset/"

train, valid, test = load_mt(path=mt_path, split=False, trim=200)

idx_to_w, w_to_idx, voc_size, freqs = get_mt_voc(path=mt_path, train_len=len(train))

# %%
word2vec_embs, word2vec_embs_mask = get_w2v_embs(mt_path)
w2v_train_mask = np.where(word2vec_embs_mask[:,0] == 1)[0]

# %%
def update_fn(loss, params):
    return L.updates.adagrad(loss, params, learning_rate=.01)

net = SimpleRNNLM(voc_size=voc_size,
                  emb_size=300,
                  rec_size=300,
                  mode='ssoft',
                  num_sampled=200,
                  emb_init=word2vec_embs)
# Out:
# Building the model...
# Compiling theano functions...
# Building a network for generation...
# Done

# %%
net.load_params(fname='5ep_w2vInit_300_300_ssoft(uni,200,non-unique)_bs50_cut200.npz')

# %%
net.train_model(num_epochs=1,
                path=None,
                save_params=False,
                train_batch_size=50,
                train_data=train,
                val_batch_size=25,
                val_data=valid)
# Out:
# Done 10 batches in 2.47s	training loss:	3.234272
# Done 20 batches in 4.74s	training loss:	2.968183
# Done 30 batches in 6.87s	training loss:	2.937981
# Done 40 batches in 9.06s	training loss:	2.850764
# Done 50 batches in 11.54s	training loss:	2.740794
# Done 60 batches in 13.70s	training loss:	2.707031
# Done 70 batches in 15.92s	training loss:	2.701926
# Done 80 batches in 18.07s	training loss:	2.645288
# Done 90 batches in 20.49s	training loss:	2.580737
# Done 100 batches in 22.59s	training loss:	2.545426
# Done 110 batches in 24.89s	training loss:	2.544325
# Done 120 batches in 27.27s	training loss:	2.506991
# Done 130 batches in 29.51s	training loss:	2.487071
# Done 140 batches in 31.81s	training loss:	2.464133
# Done 150 batches in 33.88s	training loss:	2.433267
# Done 160 batches in 36.04s	training loss:	2.403897
# Done 170 batches in 38.30s	training loss:	2.399495
# Done 180 batches in 40.61s	training loss:	2.375402
# Done 190 batches in 42.81s	training loss:	2.380579
# Done 200 batches in 45.40s	training loss:	2.351254
# Done 210 batches in 47.72s	training loss:	2.321468
# Done 220 batches in 50.09s	training loss:	2.293361
# Done 230 batches in 52.34s	training loss:	2.277796
# Done 240 batches in 54.45s	training loss:	2.257760
# Done 250 batches in 56.92s	training loss:	2.239557
# Done 260 batches in 59.23s	training loss:	2.213788
# Done 270 batches in 61.40s	training loss:	2.205937
# Done 280 batches in 63.63s	training loss:	2.190713
# Done 290 batches in 65.88s	training loss:	2.175816
# Done 300 batches in 68.27s	training loss:	2.152652
# Done 310 batches in 70.43s	training loss:	2.134306
# Done 320 batches in 72.65s	training loss:	2.117653
# Done 330 batches in 74.98s	training loss:	2.096401
# Done 340 batches in 77.24s	training loss:	2.078988
# Done 350 batches in 79.70s	training loss:	2.067495
# Done 360 batches in 81.88s	training loss:	2.063550
# Done 370 batches in 84.13s	training loss:	2.048860
# Done 380 batches in 86.50s	training loss:	2.033533
# Done 390 batches in 88.76s	training loss:	2.022782
# Done 400 batches in 90.93s	training loss:	2.011087
# Done 410 batches in 93.18s	training loss:	2.000535
# Done 420 batches in 95.58s	training loss:	1.987676
# Done 430 batches in 97.89s	training loss:	1.980058
# Done 440 batches in 100.28s	training loss:	1.968650
# Done 450 batches in 102.61s	training loss:	1.959129
# Done 460 batches in 104.86s	training loss:	1.945862
# Done 470 batches in 107.28s	training loss:	1.935808
# Done 480 batches in 109.49s	training loss:	1.928720
# Done 490 batches in 111.59s	training loss:	1.918709
# Done 500 batches in 113.81s	training loss:	1.908163
# Done 510 batches in 116.02s	training loss:	1.899040
# Done 520 batches in 118.37s	training loss:	1.890031
# Done 530 batches in 120.53s	training loss:	1.877802
# Done 540 batches in 122.74s	training loss:	1.866122
# Done 550 batches in 124.97s	training loss:	1.862067
# Done 560 batches in 127.30s	training loss:	1.853515
# Done 570 batches in 129.62s	training loss:	1.844160
# Done 580 batches in 131.65s	training loss:	1.839651
# Done 590 batches in 133.86s	training loss:	1.832838
# Done 600 batches in 136.15s	training loss:	1.830020
# Done 610 batches in 138.35s	training loss:	1.825663
# Done 620 batches in 140.83s	training loss:	1.819439
# Done 630 batches in 142.87s	training loss:	1.813570
# Done 640 batches in 145.01s	training loss:	1.808435
# Done 650 batches in 147.32s	training loss:	1.806800
# Done 660 batches in 149.43s	training loss:	1.802315
# Done 670 batches in 151.90s	training loss:	1.797941
# Done 680 batches in 154.06s	training loss:	1.791110
# Done 690 batches in 156.29s	training loss:	1.787126
# Done 700 batches in 158.35s	training loss:	1.781935
# Done 710 batches in 160.69s	training loss:	1.776226
# Done 720 batches in 163.08s	training loss:	1.768941
# Done 730 batches in 165.17s	training loss:	1.763282
# Done 740 batches in 167.43s	training loss:	1.758103
# Done 750 batches in 169.68s	training loss:	1.753656
# Done 760 batches in 171.89s	training loss:	1.749984
# Done 770 batches in 174.18s	training loss:	1.743724
# Done 780 batches in 176.37s	training loss:	1.739296
# Done 790 batches in 178.63s	training loss:	1.735019
# Done 800 batches in 180.97s	training loss:	1.731300
# Done 810 batches in 183.11s	training loss:	1.726302
# Done 820 batches in 185.32s	training loss:	1.722052
# Done 830 batches in 187.37s	training loss:	1.720859
# Done 840 batches in 189.56s	training loss:	1.716051
# Done 850 batches in 191.66s	training loss:	1.715755
# Done 860 batches in 193.87s	training loss:	1.711701
# Done 870 batches in 196.08s	training loss:	1.708455
# Done 880 batches in 198.20s	training loss:	1.705206
# Done 890 batches in 200.50s	training loss:	1.702086
# Done 900 batches in 202.66s	training loss:	1.701032
# Done 910 batches in 204.65s	training loss:	1.698352
# Done 920 batches in 206.76s	training loss:	1.694773
# Done 930 batches in 209.06s	training loss:	1.691710
# Done 940 batches in 211.28s	training loss:	1.689112
# Done 950 batches in 213.54s	training loss:	1.683843
# Done 960 batches in 215.85s	training loss:	1.678713
# Done 970 batches in 217.96s	training loss:	1.676178
# Done 980 batches in 220.19s	training loss:	1.673291
# Done 990 batches in 222.29s	training loss:	1.671326
# Done 1000 batches in 224.50s	training loss:	1.667603
# Done 1010 batches in 226.78s	training loss:	1.663892
# Done 1020 batches in 228.76s	training loss:	1.658238
# Done 1030 batches in 231.12s	training loss:	1.654714
# Done 1040 batches in 233.54s	training loss:	1.651202
# Done 1050 batches in 235.78s	training loss:	1.648911
# Done 1060 batches in 238.01s	training loss:	1.647985
# Done 1070 batches in 240.19s	training loss:	1.645503
# Done 1080 batches in 242.36s	training loss:	1.641725
# Done 1090 batches in 244.79s	training loss:	1.638952
# Done 1100 batches in 247.03s	training loss:	1.636813
# Done 1110 batches in 249.27s	training loss:	1.634069
# Done 1120 batches in 251.69s	training loss:	1.633426
# Done 1130 batches in 254.04s	training loss:	1.628940
# Done 1140 batches in 256.36s	training loss:	1.625579
# Done 1150 batches in 258.49s	training loss:	1.623359
# Done 1160 batches in 260.80s	training loss:	1.620612
# Done 1170 batches in 263.19s	training loss:	1.618678
# Done 1180 batches in 265.44s	training loss:	1.615401
# Done 1190 batches in 267.87s	training loss:	1.612508
# Done 1200 batches in 270.22s	training loss:	1.609468
# Done 1210 batches in 272.57s	training loss:	1.608394
# Done 1220 batches in 274.76s	training loss:	1.605321
# Done 1230 batches in 277.00s	training loss:	1.603026
# Done 1240 batches in 279.32s	training loss:	1.603040
# Done 1250 batches in 281.74s	training loss:	1.601057
# Done 1260 batches in 284.00s	training loss:	1.597206
# Done 1270 batches in 286.19s	training loss:	1.595598
# Done 1280 batches in 288.46s	training loss:	1.594090
# Done 1290 batches in 290.69s	training loss:	1.592244
# Done 1300 batches in 292.97s	training loss:	1.592162
# Done 1310 batches in 295.36s	training loss:	1.590390
# Done 1320 batches in 297.41s	training loss:	1.589439
# Done 1330 batches in 299.63s	training loss:	1.588173
# Done 1340 batches in 301.80s	training loss:	1.586001
# Done 1350 batches in 304.18s	training loss:	1.584024
# Done 1360 batches in 306.58s	training loss:	1.582678
# Done 1370 batches in 308.88s	training loss:	1.580815
# Done 1380 batches in 311.00s	training loss:	1.579455
# Done 1390 batches in 313.38s	training loss:	1.576492
# Done 1400 batches in 315.67s	training loss:	1.575424
# Done 1410 batches in 317.97s	training loss:	1.573369
# Done 1420 batches in 320.00s	training loss:	1.570472
# Done 1430 batches in 322.18s	training loss:	1.568547
# Done 1440 batches in 324.46s	training loss:	1.567221
# Done 1450 batches in 326.87s	training loss:	1.564739
# Done 1460 batches in 329.04s	training loss:	1.562495
# Done 1470 batches in 331.14s	training loss:	1.561173
# Done 1480 batches in 333.57s	training loss:	1.559564
# Done 1490 batches in 335.95s	training loss:	1.557618
# Done 1500 batches in 338.30s	training loss:	1.555165
# Done 1510 batches in 340.61s	training loss:	1.553451
# Done 1520 batches in 342.88s	training loss:	1.552740
# Done 1530 batches in 345.21s	training loss:	1.551471
# Done 1540 batches in 347.49s	training loss:	1.549486
# Done 1550 batches in 349.66s	training loss:	1.547608
# Done 1560 batches in 351.98s	training loss:	1.546108
# Done 1570 batches in 354.25s	training loss:	1.544656
# Done 1580 batches in 356.32s	training loss:	1.542671
# Done 1590 batches in 358.86s	training loss:	1.540295
# Done 1600 batches in 360.99s	training loss:	1.538526
# Done 1610 batches in 362.97s	training loss:	1.536690
# Done 1620 batches in 365.36s	training loss:	1.534896
# Done 1630 batches in 367.60s	training loss:	1.533818
# Done 1640 batches in 370.12s	training loss:	1.532898
# Done 1650 batches in 372.58s	training loss:	1.531240
# Done 1660 batches in 374.82s	training loss:	1.529970
# Done 1670 batches in 377.19s	training loss:	1.527892
# Done 1680 batches in 379.59s	training loss:	1.526645
# Done 1690 batches in 382.01s	training loss:	1.525071
# Done 1700 batches in 384.07s	training loss:	1.523568
# Done 1710 batches in 386.32s	training loss:	1.522430
# Done 1720 batches in 388.49s	training loss:	1.520693
# Done 1730 batches in 390.93s	training loss:	1.518676
# Done 1740 batches in 393.11s	training loss:	1.518243
# Done 1750 batches in 395.40s	training loss:	1.516844
# Done 1760 batches in 397.74s	training loss:	1.515415
# Done 1770 batches in 399.83s	training loss:	1.513674
# Done 1780 batches in 402.24s	training loss:	1.512689
# Done 1790 batches in 404.51s	training loss:	1.511557
# Done 1800 batches in 406.79s	training loss:	1.510473
# Done 1810 batches in 409.11s	training loss:	1.509074
# Done 1820 batches in 411.60s	training loss:	1.507486
# Done 1830 batches in 413.85s	training loss:	1.506163
# Done 1840 batches in 415.95s	training loss:	1.505222
# Done 1850 batches in 418.08s	training loss:	1.504018
# Done 1860 batches in 420.08s	training loss:	1.502327
# Done 1870 batches in 422.35s	training loss:	1.500695
# Done 1880 batches in 424.45s	training loss:	1.499016
# Done 1890 batches in 426.85s	training loss:	1.497241
# Done 1900 batches in 429.08s	training loss:	1.495469
# Done 1910 batches in 431.39s	training loss:	1.494504
# Done 1920 batches in 433.57s	training loss:	1.493289
# Done 1930 batches in 435.81s	training loss:	1.491413
# Done 1940 batches in 438.24s	training loss:	1.490025
# Done 1950 batches in 440.43s	training loss:	1.488048
# Done 1960 batches in 442.74s	training loss:	1.486490
# Done 1970 batches in 444.69s	training loss:	1.484916
# Done 1980 batches in 446.81s	training loss:	1.484772
# Done 1990 batches in 449.02s	training loss:	1.483146
# Done 2000 batches in 451.43s	training loss:	1.482300
# Done 2010 batches in 453.88s	training loss:	1.481608
# Done 2020 batches in 456.12s	training loss:	1.481468
# Done 2030 batches in 458.41s	training loss:	1.480698
# Done 2040 batches in 460.60s	training loss:	1.480058
# Done 2050 batches in 462.68s	training loss:	1.479424
# Done 2060 batches in 465.01s	training loss:	1.478268
# Done 2070 batches in 467.23s	training loss:	1.477153
# Done 2080 batches in 469.50s	training loss:	1.475560
# Done 2090 batches in 471.70s	training loss:	1.474440
# Done 2100 batches in 473.88s	training loss:	1.472900
# Done 2110 batches in 475.93s	training loss:	1.471303
# Done 2120 batches in 478.13s	training loss:	1.470562
# Done 2130 batches in 480.16s	training loss:	1.469500
# Done 2140 batches in 482.31s	training loss:	1.468007
# Done 2150 batches in 484.65s	training loss:	1.466547
# Done 2160 batches in 486.93s	training loss:	1.465349
# Done 2170 batches in 489.30s	training loss:	1.464097
# Done 2180 batches in 491.40s	training loss:	1.464039
# Done 2190 batches in 493.42s	training loss:	1.463396
# Done 2200 batches in 495.69s	training loss:	1.462413
# Done 2210 batches in 497.99s	training loss:	1.461225
# Done 2220 batches in 500.16s	training loss:	1.460094
# Done 2230 batches in 502.20s	training loss:	1.458542
# Done 2240 batches in 504.55s	training loss:	1.457990
# Done 2250 batches in 506.85s	training loss:	1.456606
# Done 2260 batches in 508.98s	training loss:	1.455591
# Done 2270 batches in 511.22s	training loss:	1.454058
# Done 2280 batches in 513.52s	training loss:	1.452880
# Done 2290 batches in 515.95s	training loss:	1.451990
# Done 2300 batches in 518.30s	training loss:	1.451106
# Done 2310 batches in 520.67s	training loss:	1.450386
# Done 2320 batches in 522.93s	training loss:	1.449465
# Done 2330 batches in 525.39s	training loss:	1.448093
# Done 2340 batches in 527.60s	training loss:	1.446494
# Done 2350 batches in 529.87s	training loss:	1.445777
# Done 2360 batches in 532.01s	training loss:	1.445144
# Done 2370 batches in 534.24s	training loss:	1.444081
# Done 2380 batches in 536.39s	training loss:	1.443083
# Done 2390 batches in 538.57s	training loss:	1.442272
# Done 2400 batches in 540.82s	training loss:	1.441283
# Done 2410 batches in 543.15s	training loss:	1.440308
# Done 2420 batches in 545.57s	training loss:	1.439297
# Done 2430 batches in 547.82s	training loss:	1.437873
# Done 2440 batches in 549.98s	training loss:	1.437321
# Done 2450 batches in 552.21s	training loss:	1.436070
# Done 2460 batches in 554.42s	training loss:	1.434793
# Done 2470 batches in 556.69s	training loss:	1.434010
# Done 2480 batches in 559.04s	training loss:	1.432475
# Done 2490 batches in 561.46s	training loss:	1.431745
# Done 2500 batches in 563.74s	training loss:	1.430828
# Done 2510 batches in 565.92s	training loss:	1.430484
# Done 2520 batches in 568.09s	training loss:	1.429497
# Done 2530 batches in 570.61s	training loss:	1.429219
# Done 2540 batches in 572.83s	training loss:	1.428103
# Done 2550 batches in 575.19s	training loss:	1.427006
# Done 2560 batches in 577.48s	training loss:	1.426626
# Done 2570 batches in 579.74s	training loss:	1.426125
# Done 2580 batches in 582.23s	training loss:	1.425353
# Done 2590 batches in 584.40s	training loss:	1.424775
# Done 2600 batches in 586.67s	training loss:	1.423388
# Done 2610 batches in 589.05s	training loss:	1.422214
# Done 2620 batches in 591.45s	training loss:	1.421646
# Done 2630 batches in 593.69s	training loss:	1.420752
# Done 2640 batches in 596.15s	training loss:	1.419580
# Done 2650 batches in 598.41s	training loss:	1.419606
# Done 2660 batches in 600.57s	training loss:	1.418931
# Done 2670 batches in 602.66s	training loss:	1.418181
# Done 2680 batches in 605.10s	training loss:	1.417568
# Done 2690 batches in 607.37s	training loss:	1.416707
# Done 2700 batches in 609.68s	training loss:	1.415435
# Done 2710 batches in 611.74s	training loss:	1.414349
# Done 2720 batches in 613.92s	training loss:	1.414038
# Done 2730 batches in 616.08s	training loss:	1.413486
# Done 2740 batches in 618.24s	training loss:	1.412598
# Done 2750 batches in 620.61s	training loss:	1.411632
# Done 2760 batches in 622.89s	training loss:	1.410818
# Done 2770 batches in 625.36s	training loss:	1.410475
# Done 2780 batches in 627.31s	training loss:	1.410225
# Done 2790 batches in 629.62s	training loss:	1.409994
# Done 2800 batches in 631.77s	training loss:	1.409364
# Done 2810 batches in 633.95s	training loss:	1.408519
# Done 2820 batches in 636.14s	training loss:	1.408847
# Done 2830 batches in 638.72s	training loss:	1.407877
# Done 2840 batches in 640.99s	training loss:	1.407202
# Done 2850 batches in 643.18s	training loss:	1.406647
# Done 2860 batches in 645.69s	training loss:	1.406049
# Done 2870 batches in 648.05s	training loss:	1.405238
# Done 2880 batches in 650.16s	training loss:	1.405118
# Done 2890 batches in 652.50s	training loss:	1.404363
# Done 2900 batches in 654.83s	training loss:	1.403714
# Done 2910 batches in 656.80s	training loss:	1.403169
# Done 2920 batches in 659.04s	training loss:	1.402530
# Done 2930 batches in 661.21s	training loss:	1.402018
# Done 2940 batches in 663.48s	training loss:	1.401213
# Done 2950 batches in 665.82s	training loss:	1.400364
# Done 2960 batches in 668.18s	training loss:	1.400066
# Done 2970 batches in 670.30s	training loss:	1.398927
# Done 2980 batches in 672.58s	training loss:	1.397911
# Done 2990 batches in 674.89s	training loss:	1.397445
# Done 3000 batches in 677.24s	training loss:	1.396629
# Done 3010 batches in 679.40s	training loss:	1.395853
# Done 3020 batches in 681.45s	training loss:	1.395827
# Done 3030 batches in 683.74s	training loss:	1.395458
# Done 3040 batches in 686.09s	training loss:	1.394885
# Done 3050 batches in 688.50s	training loss:	1.393905
# Done 3060 batches in 690.73s	training loss:	1.393731
# Done 3070 batches in 692.99s	training loss:	1.393166
# Done 3080 batches in 695.23s	training loss:	1.392404
# Done 3090 batches in 697.48s	training loss:	1.391717
# Done 3100 batches in 699.61s	training loss:	1.390968
# Done 3110 batches in 701.86s	training loss:	1.390293
# Done 3120 batches in 704.15s	training loss:	1.390247
# Done 3130 batches in 706.54s	training loss:	1.389676
# Done 3140 batches in 708.65s	training loss:	1.389140
# Done 3150 batches in 710.57s	training loss:	1.388400
# Done 3160 batches in 712.86s	training loss:	1.387526
# Done 3170 batches in 715.09s	training loss:	1.386241
# Done 3180 batches in 717.43s	training loss:	1.385161
# Done 3190 batches in 719.66s	training loss:	1.384676
# Done 3200 batches in 721.89s	training loss:	1.383982
# Done 3210 batches in 724.10s	training loss:	1.383827
# Done 3220 batches in 726.39s	training loss:	1.383001
# Done 3230 batches in 728.76s	training loss:	1.382049
# Done 3240 batches in 731.05s	training loss:	1.381629
# Done 3250 batches in 733.30s	training loss:	1.380525
# Done 3260 batches in 735.45s	training loss:	1.379797
# Done 3270 batches in 737.78s	training loss:	1.379330
# Done 3280 batches in 740.21s	training loss:	1.378445
# Done 3290 batches in 742.30s	training loss:	1.377750
# Done 3300 batches in 744.64s	training loss:	1.377071
# Done 3310 batches in 746.77s	training loss:	1.377246
# Done 3320 batches in 748.85s	training loss:	1.376440
# Done 3330 batches in 751.22s	training loss:	1.375552
# Done 3340 batches in 753.46s	training loss:	1.375230
# Done 3350 batches in 755.74s	training loss:	1.374615
# Done 3360 batches in 757.95s	training loss:	1.373953
# Done 3370 batches in 760.23s	training loss:	1.374022
# Done 3380 batches in 762.45s	training loss:	1.373225
# Done 3390 batches in 764.58s	training loss:	1.373525
# Done 3400 batches in 766.85s	training loss:	1.372976
# Done 3410 batches in 769.14s	training loss:	1.372519
# Done 3420 batches in 771.17s	training loss:	1.371982
# Done 3430 batches in 773.27s	training loss:	1.371247
# Done 3440 batches in 775.49s	training loss:	1.371345
# Done 3450 batches in 777.59s	training loss:	1.371166
# Done 3460 batches in 779.95s	training loss:	1.370472
# Done 3470 batches in 782.18s	training loss:	1.369669
# Done 3480 batches in 784.44s	training loss:	1.368929
# Done 3490 batches in 786.75s	training loss:	1.368527
# Done 3500 batches in 789.11s	training loss:	1.368134
# Done 3510 batches in 791.34s	training loss:	1.367753
# Done 3520 batches in 793.56s	training loss:	1.367095
# Done 3530 batches in 795.66s	training loss:	1.366539
# Done 3540 batches in 797.91s	training loss:	1.365873
# Done 3550 batches in 799.98s	training loss:	1.365272
# Done 3560 batches in 802.40s	training loss:	1.364922
# Done 3570 batches in 804.71s	training loss:	1.364254
# Done 3580 batches in 807.00s	training loss:	1.363724
# Done 3590 batches in 809.35s	training loss:	1.362898
# Done 3600 batches in 811.82s	training loss:	1.362231
# Done 3610 batches in 814.17s	training loss:	1.361807
# Done 3620 batches in 816.20s	training loss:	1.361099
# Done 3630 batches in 818.28s	training loss:	1.360773
# Done 3640 batches in 820.58s	training loss:	1.360238
# Done 3650 batches in 822.87s	training loss:	1.359594
# Done 3660 batches in 825.00s	training loss:	1.359301
# Done 3670 batches in 827.11s	training loss:	1.359206
# Done 3680 batches in 829.21s	training loss:	1.358709
# Done 3690 batches in 831.35s	training loss:	1.358376
# Done 3700 batches in 833.66s	training loss:	1.357824
# Done 3710 batches in 835.76s	training loss:	1.357110
# Done 3720 batches in 837.96s	training loss:	1.356263
# Done 3730 batches in 840.10s	training loss:	1.355623
# Done 3740 batches in 842.37s	training loss:	1.354781
# Done 3750 batches in 844.56s	training loss:	1.354509
# Done 3760 batches in 846.90s	training loss:	1.354550
# Done 3770 batches in 849.06s	training loss:	1.354235
# Done 3780 batches in 851.21s	training loss:	1.353572
# Done 3790 batches in 853.50s	training loss:	1.352628
# Done 3800 batches in 855.81s	training loss:	1.352429
# Done 3810 batches in 858.12s	training loss:	1.352184
# Done 3820 batches in 860.49s	training loss:	1.351460
# Done 3830 batches in 862.61s	training loss:	1.350890
# Done 3840 batches in 864.94s	training loss:	1.350126
# Done 3850 batches in 867.46s	training loss:	1.350326
# Done 3860 batches in 869.79s	training loss:	1.349386
# Done 3870 batches in 872.09s	training loss:	1.349143
# Done 3880 batches in 874.35s	training loss:	1.349018
# Done 3890 batches in 876.44s	training loss:	1.348421
# Done 100 batches in 6.78s
# Done 200 batches in 13.47s
# Done 300 batches in 20.07s
# Done 400 batches in 26.75s
# Done 500 batches in 33.82s
# Done 600 batches in 40.36s
# Done 700 batches in 47.20s
# Done 800 batches in 53.95s
# Done 900 batches in 60.90s
# Epoch 1 of 1 took 945.32s
#   training loss:		1.348201
#   validation loss:		3.989319

# %%
def rnd_next_word(probs, size=1):
    return np.random.choice(np.append(np.arange(probs.shape[0]-1), -1).astype(np.int32), 
                            size=size, p=probs)

def beam_search(get_probs_fun, beam=10, init_seq='', mode='rr'):
    utt = map(lambda w: w_to_idx.get(w, w_to_idx['<unk>']), init_seq.split())
    if len(utt) == 0 or utt[0] != 1:
        utt = [1] + utt
    utt = np.asarray(utt, dtype=np.int32)[np.newaxis]
    
    if mode[0] == 's':
        words = get_probs_fun(utt)[0].argpartition(-beam)[-beam:].astype(np.int32)
        words[words==voc_size-1] = pad_value
    elif mode[0] == 'r':
        words = rnd_next_word(get_probs_fun(utt)[0], beam)
    
    candidates = utt.repeat(beam, axis=0)
    candidates = np.hstack([candidates, words[np.newaxis].T])
    scores = np.zeros(beam)
    
#     print candidates
    
    while candidates.shape[1] < 100 and pad_value not in candidates[:,-1]:
        
        if mode[1] == 's':
            log_probs = np.log(get_probs_fun(candidates))
            tot_scores = log_probs + scores[np.newaxis].T

            idx = tot_scores.ravel().argpartition(-beam)[-beam:]
            i,j = divmod(idx, tot_scores.shape[1])
            j[j==voc_size-1] = pad_value
            
            scores = tot_scores[i,j]

            candidates = np.hstack([candidates[i], j[np.newaxis].T.astype(np.int32)])
            
        elif mode[1] == 'r':
            probs = get_probs_fun(candidates)
            words = []
            for k in xrange(beam):
                words.append(rnd_next_word(probs[k], beam)) # this doesn't have to be exactly 'beam'
            words = np.array(words)
            idx = np.indices((beam, words.shape[1]))[0]
            tot_scores = scores[np.newaxis].T + np.log(probs)[idx, words]
                
            idx = tot_scores.ravel().argpartition(-beam)[-beam:]
            i,j = divmod(idx, tot_scores.shape[1])

            scores = tot_scores[i,j]

            candidates = np.hstack([candidates[i], words[i,j][np.newaxis].T])
            
#     print candidates[:,:10]
#     print scores[:10]
        
    cands = candidates[candidates[:,-1] == pad_value]
    if cands.size > 0:
        return candidates[candidates[:,-1] == pad_value][0]
    return candidates[scores.argmax()]

# %%
utt = beam_search(net.get_probs_fn, init_seq='', beam=10, mode='rr')

text = map(lambda i: idx_to_w[i], list(utt))
' '.join([t for t in text])# if t not in ['<s>', '</s>', '<utt_end>']])
# Out:
# "<s> excuse me ? </s> <s> i ' m not going to be a lot of time . </s> <s> i ' m not going to be a <unk> . </s> <s> i ' m not going to be a long time . </s> <s> i ' m not . </s> <s> i ' m not going to be a lot of time . </s> <s> i ' m not going to be a lot of time . </s> <s> i ' m not going to be a lot of <unk> . </s> <s> i ' m not a <unk> . </s> <s> i ' m not going to be a lot of <unk> . </s> <s> i ' m not going to be a lot of time . </s> <s> i ' m not going to be a lot of <unk> . </s> <s> i ' m not going to be a lot of time . </s> <s> i ' m not going to be a man . </s> <s> i ' m not going to be a lot of time . </s> <s> i ' m not going to be a lot of time . </s> <s> i ' m not going to be a <unk> . </s> <s> i ' m not going to be a lot of time . </s> <s> i ' m not going to be a lot of time . </s> <s> i ' m not going to be a lot of time . </s> <s> i ' m not going to be a lot of <unk> . </s> <s> i ' m not a <unk> . </s> <s> i ' m not going to be a lot of time . </s> <s> i ' m not going to tell you what i ' m going to be . </s> <s> i ' m not going to be a <unk> . </s> <s> i ' m not going to be a lot of time . </s> <s> i ' m not going to be a lot of time . </s> <s> i ' m not . </s> <s> i ' m not a <unk> . </s> <s> i ' m not going to be a <unk> . </s> <s> i ' m not . </s> <s> i ' m not going to be a lot of time . </s> <s> i ' m not going to be a lot of <unk> . </s> <s> i ' m not going to be a lot of <unk> . </s> <s> i ' m not going to be a lot of time . </s> <s> i ' m not going to be a <unk> . </s> <s> i ' m not going to be a <unk> . </s> <s> i ' m not going to be a lot of time . </s> <s> i ' m not going to be a lot of time . </s> <s> i ' m not going to be a lot"

# %%
init_seq = ''
utt = [1] + map(lambda w: w_to_idx.get(w, w_to_idx['<unk>']), init_seq.split())
utt = np.asarray(utt, dtype=np.int32)[np.newaxis]

i = 0
while utt[0,-1] != -1 and i < 100:
    word_probs = net.get_probs_fn(utt)[0]
    next_idx = rnd_next_word(word_probs)
    utt = np.append(utt, next_idx)[np.newaxis].astype(np.int32)
    i += 1
    
text = map(lambda i: idx_to_w[i], list(utt[0]))
' '.join([t for t in text if t not in ['<s>', '</s>', '<utt_end>']])
# Out:
# "so you do big bones . an instant spa news name ? what do you remember she seem good about your production assistant ? right with the bouquet after the street . these that ' s always a gentlemen , as it would not happen . one of the premium sessions . that was they is innocent by somebody ' s making ok , i can bust four hundred examiner hundred up , <number> authority -- it may sign of me too you called the f <unk> chamber , exactly what is that ?"
