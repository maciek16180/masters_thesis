# %%
import json, nltk, pickle
import numpy as np

# %%
train = np.load('/pio/data/data/squad/glove6B/train.pkl')

# %%
train_words = np.load('/pio/data/data/squad/glove6B/train_words.pkl')

# %%
train_char = np.load('/pio/data/data/squad/glove6B/train_char_ascii.pkl')
train_bin_feats = np.load('/pio/data/data/squad/glove6B/train_bin_feats.pkl')

# %%
def cut_sentence_with_ans(ans, context):
    i, j = min(ans), max(ans)
    while i > 0 and context[i-1] != '.':
        i -= 1
    while context[j] != '.' and j < len(context) - 1:
        j += 1
    return i, j + 1

# %%
NAW_tok = u'<not_a_word>'
NAW_idx = 400001
NAW_chars = [1, 3, 2]

# %%
train_new = []
train_words_new = []
train_char_new = []
train_bin_feats_new = []

for k in range(len(train)):
    if not train_words[k][0]:
        continue
        
    ans = train_words[k][0][0]
    i, j = cut_sentence_with_ans(ans, train[k][2])
    
    new_raw = train[k][2][:i] + train[k][2][j:] + [NAW_tok]
    train_new.append([[], train[k][1], new_raw])
    
    new_words = train_words[k][2][:i] + train_words[k][2][j:] + [NAW_idx]
    new_ans = [[len(new_words) - 1]]
    train_words_new.append([new_ans, train_words[k][1], new_words])
    
    new_char = train_char[k][1][:i] + train_char[k][1][j:] + [NAW_chars]
    train_char_new.append([train_char[k], new_char])
    
    new_bin_feats = train_bin_feats[k][:i] + train_bin_feats[k][j:] + [False]
    train_bin_feats_new.append(new_bin_feats)

# %%
train[101]
# Out:
# [[(251, [u'13'])],
#  [u'how',
#   u'many',
#   u'years',
#   u'was',
#   u'knute',
#   u'rockne',
#   u'head',
#   u'coach',
#   u'at',
#   u'notre',
#   u'dame',
#   u'?'],
#  [u'one',
#   u'of',
#   u'the',
#   u'main',
#   u'driving',
#   u'forces',
#   u'in',
#   u'the',
#   u'growth',
#   u'of',
#   u'the',
#   u'university',
#   u'was',
#   u'its',
#   u'football',
#   u'team',
#   u',',
#   u'the',
#   u'notre',
#   u'dame',
#   u'fighting',
#   u'irish',
#   u'.',
#   u'knute',
#   u'rockne',
#   u'became',
#   u'head',
#   u'coach',
#   u'in',
#   u'1918',
#   u'.',
#   u'under',
#   u'rockne',
#   u',',
#   u'the',
#   u'irish',
#   u'would',
#   u'post',
#   u'a',
#   u'record',
#   u'of',
#   u'105',
#   u'wins',
#   u',',
#   u'12',
#   u'losses',
#   u',',
#   u'and',
#   u'five',
#   u'ties',
#   u'.',
#   u'during',
#   u'his',
#   u'13',
#   u'years',
#   u'the',
#   u'irish',
#   u'won',
#   u'three',
#   u'national',
#   u'championships',
#   u',',
#   u'had',
#   u'five',
#   u'undefeated',
#   u'seasons',
#   u',',
#   u'won',
#   u'the',
#   u'rose',
#   u'bowl',
#   u'in',
#   u'1925',
#   u',',
#   u'and',
#   u'produced',
#   u'players',
#   u'such',
#   u'as',
#   u'george',
#   u'gipp',
#   u'and',
#   u'the',
#   u'``',
#   u'four',
#   u'horsemen',
#   u"''",
#   u'.',
#   u'knute',
#   u'rockne',
#   u'has',
#   u'the',
#   u'highest',
#   u'winning',
#   u'percentage',
#   u'(',
#   u'.881',
#   u')',
#   u'in',
#   u'ncaa',
#   u'division',
#   u'i/fbs',
#   u'football',
#   u'history',
#   u'.',
#   u'rockne',
#   u"'s",
#   u'offenses',
#   u'employed',
#   u'the',
#   u'notre',
#   u'dame',
#   u'box',
#   u'and',
#   u'his',
#   u'defenses',
#   u'ran',
#   u'a',
#   u'7\u20132\u20132',
#   u'scheme',
#   u'.',
#   u'the',
#   u'last',
#   u'game',
#   u'rockne',
#   u'coached',
#   u'was',
#   u'on',
#   u'december',
#   u'14',
#   u',',
#   u'1930',
#   u'when',
#   u'he',
#   u'led',
#   u'a',
#   u'group',
#   u'of',
#   u'notre',
#   u'dame',
#   u'all-stars',
#   u'against',
#   u'the',
#   u'new',
#   u'york',
#   u'giants',
#   u'in',
#   u'new',
#   u'york',
#   u'city',
#   u'.']]

# %%
with open('/pio/data/data/squad/glove6B/squad_negative/train_neg_words.pkl', 'w') as f:
    pickle.dump(train_words_new, f)
    
with open('/pio/data/data/squad/glove6B/squad_negative/train_neg_char.pkl', 'w') as f:
    pickle.dump(train_char_new, f)
    
with open('/pio/data/data/squad/glove6B/squad_negative/train_neg_bin_feats.pkl', 'w') as f:
    pickle.dump(train_bin_feats_new, f)
    
with open('/pio/data/data/squad/glove6B/squad_negative/train_neg.pkl', 'w') as f:
    pickle.dump(train_new, f)
