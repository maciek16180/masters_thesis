# %%
import numpy as np
import theano
import theano.tensor as T
import time

import lasagne as L

import sys
sys.path.insert(0, '../rnn_ex/')

from SimpleRNNLM import iterate_minibatches
from SampledSoftmaxLayer import SampledSoftmaxDenseLayer
from mt_load import load_mt, get_mt_voc, get_w2v_embs

from ShiftLayer import ShiftLayer
from L2PoolingLayer import L2PoolingLayer
# Out:
# WARNING (theano.sandbox.cuda): The cuda backend is deprecated and will be removed in the next release (v0.10).  Please switch to the gpuarray backend. You can get more information about how to switch at this URL:
#  https://github.com/Theano/Theano/wiki/Converting-to-the-new-gpu-back-end%28gpuarray%29
#
# Using gpu device 0: GeForce GTX 780 (CNMeM is enabled with initial size: 30.0% of memory, cuDNN 5105)

# %%
# remember, now the pad value is the same as the <utt_end> token

pad_value = -1 # <utt_end>'s vector is the last one

# %%
mt_path = "/pio/data/data/mtriples/"
# mt_path = "/home/maciek/Desktop/mgr/DATA/MovieTriples_Dataset/"

train, valid, test = load_mt(path=mt_path, split=True, trim=200)
idx_to_w, w_to_idx, voc_size, freqs = get_mt_voc(path=mt_path, train_len=len(train))

# %%
word2vec_embs, word2vec_embs_mask = get_w2v_embs(path=mt_path)

w2v_train_mask = np.where(word2vec_embs_mask[:,0] == 1)[0]

# %%
def build_hred(input_var, mask_input_var, voc_size, emb_size, lv1_rec_size, lv2_rec_size, out_emb_size,
               num_sampled, ssoft_probs=None, emb_init=None, train_emb=True, target_var=None):
    l_in = L.layers.InputLayer(shape=(None, None), input_var=input_var)
    
    l_mask = None
    if mask_input_var is not None:
        l_mask = L.layers.InputLayer(shape=(None, None), input_var=mask_input_var)
    
    if emb_init is None:
        l_emb = L.layers.EmbeddingLayer(l_in,
                                        input_size=voc_size,  # not voc_size+1, because pad_value = <utt_end>
                                        output_size=emb_size)
    else:
        l_emb = L.layers.EmbeddingLayer(l_in,
                                        input_size=voc_size,
                                        output_size=emb_size,
                                        W=emb_init)
        if not train_emb:
            l_emb.params[l_emb.W].remove('trainable')
            
    l_lv1_enc_forw = L.layers.GRULayer(l_emb, # we process all utts in parallel, out_shape is batch_size x lv1_rec_size
                                       num_units=lv1_rec_size,
                                       grad_clipping=100,
#                                        only_return_final=True,
                                       mask_input=l_mask)
    
    ###
    
    l_lv1_enc_back = L.layers.GRULayer(l_emb, # backward pass of encoder rnn, out_shape is batch_size x lv1_rec_size
                                       num_units=lv1_rec_size,
                                       grad_clipping=100,
#                                        only_return_final=True,
                                       mask_input=l_mask,
                                       backwards=True)
    
    l2_pooled_forw = L2PoolingLayer(l_lv1_enc_forw)
    l2_pooled_back = L2PoolingLayer(l_lv1_enc_back)

    l_lv1_enc = L.layers.ConcatLayer([l2_pooled_forw, l2_pooled_back], axis=1) # concatenation of L2-pooled states
    
    ###    
    
    l_resh = L.layers.ReshapeLayer(l_lv1_enc, shape=(-1, 3, 2*lv1_rec_size)) # 3 is because movie *triples*
    
    l_lv2_enc = L.layers.GRULayer(l_resh, # out_shape is batch_size/3 x 3 x lv2_rec_size
                                  num_units=lv2_rec_size,
                                  grad_clipping=100)
    
    l_shift = ShiftLayer(l_lv2_enc)

    l_resh2 = L.layers.ReshapeLayer(l_shift, shape=(-1, lv2_rec_size))
    
    l_dec_inits = L.layers.DenseLayer(l_resh2, # out_shape is batch_size x lv1_rec_size
                                      num_units=lv1_rec_size,
                                      nonlinearity=L.nonlinearities.tanh)
    
    l_dec = L.layers.GRULayer(l_emb, # out_shape is batch_size x seq_len x lv1_rec_size
                              num_units=lv1_rec_size,
                              grad_clipping=100,
                              mask_input=l_mask,
                              hid_init=l_dec_inits)
    
    l_resh3 = L.layers.ReshapeLayer(l_dec, shape=(-1, lv1_rec_size))
    
    l_H0 = L.layers.DenseLayer(l_resh3,
                               num_units=out_emb_size,
                               nonlinearity=None)
    
    l_resh4 = L.layers.ReshapeLayer(l_emb, shape=(-1, emb_size))
    
    l_E0 = L.layers.DenseLayer(l_resh4,
                               num_units=out_emb_size,
                               b=None,
                               nonlinearity=None)
    
    l_soft_in = L.layers.ElemwiseSumLayer([l_H0, l_E0])
    
#     l_soft = L.layers.DenseLayer(l_soft_in,
#                                  num_units=voc_size,
#                                  nonlinearity=L.nonlinearities.softmax)
    
#     l_out = L.layers.ReshapeLayer(l_soft, shape=(input_var.shape[0], input_var.shape[1], voc_size))

    if target_var is not None:
        target_var = target_var.ravel()

    l_ssoft = SampledSoftmaxDenseLayer(l_soft_in, num_sampled, voc_size,
                                       targets=target_var,
                                       probs=ssoft_probs,
                                       sample_unique=False)

    if target_var is not None:
        l_out = L.layers.ReshapeLayer(l_ssoft, shape=(input_var.shape[0], input_var.shape[1]))
    else:
        l_out = L.layers.ReshapeLayer(l_ssoft, shape=(input_var.shape[0], input_var.shape[1], voc_size))

    return l_out

# %%
emb_size = 300
lv1_rec_size = 300
lv2_rec_size = 300
out_emb_size = 300

update_fn = lambda l, p: L.updates.adagrad(l, p, learning_rate=.01)

# %%
# for ssoft

num_sampled = 200

input_var = T.imatrix('inputs')
target_var = T.imatrix('targets')  # these will be inputs shifted by 1
mask_input_var = T.matrix('input_mask')
mask_idx = mask_input_var.nonzero()

net = build_hred(input_var, mask_input_var, voc_size, emb_size, lv1_rec_size, lv2_rec_size, out_emb_size,
                 num_sampled, ssoft_probs=freqs, emb_init=word2vec_embs, target_var=target_var)

train_out = L.layers.get_output(net)
test_out = L.layers.get_output(net, deterministic=True)

train_loss = -T.log(train_out[mask_idx]).mean()
test_loss = -T.log(test_out[mask_idx]).mean()

params = L.layers.get_all_params(net, trainable=True)
updates = update_fn(train_loss, params)

print 'Compiling theano functions...'

train_fn = theano.function([input_var, target_var, mask_input_var], train_loss, updates=updates)
val_fn = theano.function([input_var, target_var, mask_input_var], test_loss)
# Out:
# Compiling theano functions...

# %%
input_var = T.imatrix('inputs')
target_var = T.imatrix('targets')  # these will be inputs shifted by 1
mask_input_var = T.matrix('input_mask')
mask_idx = mask_input_var.nonzero()

net = build_hred(input_var, mask_input_var, voc_size, emb_size, lv1_rec_size, lv2_rec_size, out_emb_size,
                 emb_init=word2vec_embs)

train_out = L.layers.get_output(net)
test_out = L.layers.get_output(net, deterministic=True)

train_loss = L.objectives.categorical_crossentropy(train_out[mask_idx], target_var[mask_idx]).mean()
test_loss = L.objectives.categorical_crossentropy(test_out[mask_idx], target_var[mask_idx]).mean()

params = L.layers.get_all_params(net, trainable=True)
updates = update_fn(train_loss, params)

print 'Compiling theano functions...'

train_fn = theano.function([input_var, target_var, mask_input_var], train_loss, updates=updates)
val_fn = theano.function([input_var, target_var, mask_input_var], test_loss)
# Out:
# Compiling theano functions...

# %%
def train_one_epoch(train_data, batch_size, log_interval=10):
    train_err = 0.
    train_batches = 0
    num_training_words = 0
    start_time = time.time()

    for batch in iterate_minibatches(train_data, batch_size, pad_value):
        inputs, targets, mask = batch

        num_batch_words = mask.sum()
        train_err += train_fn(inputs, targets, mask) * num_batch_words
        train_batches += 1
        num_training_words += num_batch_words

        if not train_batches % log_interval:
            print "Done {} batches in {:.2f}s\ttraining loss:\t{:.6f}".format(
                train_batches, time.time() - start_time, train_err / num_training_words)

    return  train_err / num_training_words

# %%
# train, 1 dir, 1 epoch: 3.485554076321884
# val: 3.455356876018342

# train, 2 dir, concat, 1 epoch: 3.4864403798772239
# val: 3.4579001751897063

# train, 2 dir, L2 + concat, 1 epoch: 3.4881669768474675
# val: 3.4584704095551695
# training time: ~4700s

'''with sampled softmax'''
# train, 2 dir, L2 + concat, 1 epoch: 3.486180601246621
# val: 3.4811877499289308
# training time: ~2300s

# %%
train_one_epoch(train, 30)
# Out:
# Done 10 batches in 1.18s	training loss:	7.237148
# Done 20 batches in 2.22s	training loss:	6.233935
# Done 30 batches in 3.49s	training loss:	5.808175
# Done 40 batches in 4.61s	training loss:	5.549267
# Done 50 batches in 5.72s	training loss:	5.338073
# Done 60 batches in 7.29s	training loss:	5.177397
# Done 70 batches in 8.45s	training loss:	5.069123
# Done 80 batches in 9.60s	training loss:	4.967996
# Done 90 batches in 10.89s	training loss:	4.892198
# Done 100 batches in 12.12s	training loss:	4.827950
# Done 110 batches in 13.00s	training loss:	4.769821
# Done 120 batches in 14.28s	training loss:	4.724219
# Done 130 batches in 15.37s	training loss:	4.678354
# Done 140 batches in 16.57s	training loss:	4.638821
# Done 150 batches in 17.73s	training loss:	4.606170
# Done 160 batches in 19.02s	training loss:	4.572973
# Done 170 batches in 19.94s	training loss:	4.545257
# Done 180 batches in 21.09s	training loss:	4.523121
# Done 190 batches in 22.22s	training loss:	4.499238
# Done 200 batches in 23.31s	training loss:	4.477982
# Done 210 batches in 24.56s	training loss:	4.458469
# Done 220 batches in 25.58s	training loss:	4.438176
# Done 230 batches in 26.61s	training loss:	4.419114
# Done 240 batches in 27.83s	training loss:	4.401739
# Done 250 batches in 29.18s	training loss:	4.384742
# Done 260 batches in 30.44s	training loss:	4.368549
# Done 270 batches in 31.71s	training loss:	4.353635
# Done 280 batches in 32.66s	training loss:	4.340064
# Done 290 batches in 33.88s	training loss:	4.325959
# Done 300 batches in 35.16s	training loss:	4.313627
# Done 310 batches in 36.38s	training loss:	4.301468
# Done 320 batches in 37.46s	training loss:	4.289131
# Done 330 batches in 38.72s	training loss:	4.276251
# Done 340 batches in 39.91s	training loss:	4.267939
# Done 350 batches in 41.19s	training loss:	4.257129
# Done 360 batches in 42.40s	training loss:	4.247888
# Done 370 batches in 43.62s	training loss:	4.237215
# Done 380 batches in 44.73s	training loss:	4.229982
# Done 390 batches in 45.81s	training loss:	4.221287
# Done 400 batches in 46.72s	training loss:	4.214120
# Done 410 batches in 47.89s	training loss:	4.206042
# Done 420 batches in 49.02s	training loss:	4.198816
# Done 430 batches in 50.12s	training loss:	4.190709
# Done 440 batches in 51.19s	training loss:	4.184060
# Done 450 batches in 52.39s	training loss:	4.176550
# Done 460 batches in 53.34s	training loss:	4.169543
# Done 470 batches in 54.49s	training loss:	4.163813
# Done 480 batches in 55.70s	training loss:	4.158300
# Done 490 batches in 57.06s	training loss:	4.152093
# Done 500 batches in 58.13s	training loss:	4.145299
# Done 510 batches in 59.15s	training loss:	4.139744
# Done 520 batches in 60.43s	training loss:	4.133571
# Done 530 batches in 61.54s	training loss:	4.129237
# Done 540 batches in 62.79s	training loss:	4.124439
# Done 550 batches in 64.13s	training loss:	4.118369
# Done 560 batches in 65.28s	training loss:	4.113340
# Done 570 batches in 66.74s	training loss:	4.108086
# Done 580 batches in 67.88s	training loss:	4.102870
# Done 590 batches in 69.06s	training loss:	4.099778
# Done 600 batches in 70.41s	training loss:	4.095715
# Done 610 batches in 71.74s	training loss:	4.090827
# Done 620 batches in 72.85s	training loss:	4.086598
# Done 630 batches in 73.80s	training loss:	4.081572
# Done 640 batches in 75.21s	training loss:	4.078434
# Done 650 batches in 76.46s	training loss:	4.073512
# Done 660 batches in 77.60s	training loss:	4.069626
# Done 670 batches in 78.71s	training loss:	4.064803
# Done 680 batches in 79.93s	training loss:	4.061120
# Done 690 batches in 81.02s	training loss:	4.057825
# Done 700 batches in 82.29s	training loss:	4.054412
# Done 710 batches in 83.65s	training loss:	4.050456
# Done 720 batches in 84.63s	training loss:	4.047000
# Done 730 batches in 85.82s	training loss:	4.042787
# Done 740 batches in 86.97s	training loss:	4.039455
# Done 750 batches in 87.93s	training loss:	4.035677
# Done 760 batches in 88.91s	training loss:	4.031750
# Done 770 batches in 90.09s	training loss:	4.028024
# Done 780 batches in 91.10s	training loss:	4.024347
# Done 790 batches in 92.07s	training loss:	4.021343
# Done 800 batches in 93.04s	training loss:	4.017981
# Done 810 batches in 94.08s	training loss:	4.015610
# Done 820 batches in 95.56s	training loss:	4.012066
# Done 830 batches in 96.66s	training loss:	4.009604
# Done 840 batches in 97.80s	training loss:	4.006399
# Done 850 batches in 98.92s	training loss:	4.003266
# Done 860 batches in 99.86s	training loss:	4.000136
# Done 870 batches in 101.02s	training loss:	3.997031
# Done 880 batches in 102.11s	training loss:	3.993863
# Done 890 batches in 103.21s	training loss:	3.991048
# Done 900 batches in 104.44s	training loss:	3.987766
# Done 910 batches in 105.79s	training loss:	3.984919
# Done 920 batches in 107.08s	training loss:	3.982915
# Done 930 batches in 108.15s	training loss:	3.980345
# Done 940 batches in 109.17s	training loss:	3.977929
# Done 950 batches in 110.43s	training loss:	3.976427
# Done 960 batches in 111.73s	training loss:	3.974450
# Done 970 batches in 112.79s	training loss:	3.971714
# Done 980 batches in 114.00s	training loss:	3.969617
# Done 990 batches in 115.20s	training loss:	3.967594
# Done 1000 batches in 116.44s	training loss:	3.965559
# Done 1010 batches in 117.50s	training loss:	3.963403
# Done 1020 batches in 118.58s	training loss:	3.961639
# Done 1030 batches in 119.67s	training loss:	3.959381
# Done 1040 batches in 120.72s	training loss:	3.957012
# Done 1050 batches in 121.95s	training loss:	3.954511
# Done 1060 batches in 123.03s	training loss:	3.952193
# Done 1070 batches in 124.33s	training loss:	3.950095
# Done 1080 batches in 125.96s	training loss:	3.948644
# Done 1090 batches in 127.08s	training loss:	3.946556
# Done 1100 batches in 128.15s	training loss:	3.944805
# Done 1110 batches in 129.25s	training loss:	3.943558
# Done 1120 batches in 130.31s	training loss:	3.941557
# Done 1130 batches in 131.50s	training loss:	3.939606
# Done 1140 batches in 132.58s	training loss:	3.937560
# Done 1150 batches in 133.58s	training loss:	3.936093
# Done 1160 batches in 134.66s	training loss:	3.934330
# Done 1170 batches in 135.58s	training loss:	3.932205
# Done 1180 batches in 136.75s	training loss:	3.930177
# Done 1190 batches in 137.83s	training loss:	3.927877
# Done 1200 batches in 139.08s	training loss:	3.925774
# Done 1210 batches in 140.04s	training loss:	3.924288
# Done 1220 batches in 141.35s	training loss:	3.922644
# Done 1230 batches in 142.53s	training loss:	3.920608
# Done 1240 batches in 143.85s	training loss:	3.919831
# Done 1250 batches in 145.12s	training loss:	3.918512
# Done 1260 batches in 146.38s	training loss:	3.916849
# Done 1270 batches in 147.64s	training loss:	3.915541
# Done 1280 batches in 148.82s	training loss:	3.913600
# Done 1290 batches in 150.07s	training loss:	3.912049
# Done 1300 batches in 151.31s	training loss:	3.910059
# Done 1310 batches in 152.24s	training loss:	3.908421
# Done 1320 batches in 153.29s	training loss:	3.907072
# Done 1330 batches in 154.56s	training loss:	3.905641
# Done 1340 batches in 156.07s	training loss:	3.904469
# Done 1350 batches in 157.42s	training loss:	3.902516
# Done 1360 batches in 158.60s	training loss:	3.900861
# Done 1370 batches in 159.74s	training loss:	3.898634
# Done 1380 batches in 160.70s	training loss:	3.897148
# Done 1390 batches in 161.85s	training loss:	3.895925
# Done 1400 batches in 162.83s	training loss:	3.894104
# Done 1410 batches in 164.15s	training loss:	3.892303
# Done 1420 batches in 165.43s	training loss:	3.890574
# Done 1430 batches in 166.51s	training loss:	3.889172
# Done 1440 batches in 167.56s	training loss:	3.887783
# Done 1450 batches in 168.76s	training loss:	3.886269
# Done 1460 batches in 169.98s	training loss:	3.885224
# Done 1470 batches in 171.27s	training loss:	3.883623
# Done 1480 batches in 172.19s	training loss:	3.881868
# Done 1490 batches in 173.48s	training loss:	3.880741
# Done 1500 batches in 174.54s	training loss:	3.878995
# Done 1510 batches in 175.52s	training loss:	3.877460
# Done 1520 batches in 176.75s	training loss:	3.876248
# Done 1530 batches in 177.92s	training loss:	3.874637
# Done 1540 batches in 179.08s	training loss:	3.873828
# Done 1550 batches in 180.35s	training loss:	3.872514
# Done 1560 batches in 181.52s	training loss:	3.871323
# Done 1570 batches in 182.88s	training loss:	3.869746
# Done 1580 batches in 184.18s	training loss:	3.868571
# Done 1590 batches in 185.19s	training loss:	3.867411
# Done 1600 batches in 186.14s	training loss:	3.866365
# Done 1610 batches in 187.35s	training loss:	3.864975
# Done 1620 batches in 188.58s	training loss:	3.864208
# Done 1630 batches in 189.64s	training loss:	3.862893
# Done 1640 batches in 190.64s	training loss:	3.861747
# Done 1650 batches in 191.76s	training loss:	3.860659
# Done 1660 batches in 192.76s	training loss:	3.859753
# Done 1670 batches in 194.04s	training loss:	3.858486
# Done 1680 batches in 195.31s	training loss:	3.857418
# Done 1690 batches in 196.43s	training loss:	3.856352
# Done 1700 batches in 197.48s	training loss:	3.855251
# Done 1710 batches in 198.34s	training loss:	3.854013
# Done 1720 batches in 199.53s	training loss:	3.853381
# Done 1730 batches in 200.74s	training loss:	3.852217
# Done 1740 batches in 201.74s	training loss:	3.851049
# Done 1750 batches in 203.28s	training loss:	3.850203
# Done 1760 batches in 204.29s	training loss:	3.849274
# Done 1770 batches in 205.50s	training loss:	3.848253
# Done 1780 batches in 206.58s	training loss:	3.847325
# Done 1790 batches in 207.88s	training loss:	3.845910
# Done 1800 batches in 209.44s	training loss:	3.845350
# Done 1810 batches in 210.44s	training loss:	3.844410
# Done 1820 batches in 211.61s	training loss:	3.843652
# Done 1830 batches in 212.69s	training loss:	3.842385
# Done 1840 batches in 213.76s	training loss:	3.841234
# Done 1850 batches in 214.92s	training loss:	3.840516
# Done 1860 batches in 216.09s	training loss:	3.839338
# Done 1870 batches in 217.17s	training loss:	3.838487
# Done 1880 batches in 218.33s	training loss:	3.837571
# Done 1890 batches in 219.56s	training loss:	3.836795
# Done 1900 batches in 220.52s	training loss:	3.835794
# Done 1910 batches in 221.67s	training loss:	3.834818
# Done 1920 batches in 222.74s	training loss:	3.834016
# Done 1930 batches in 223.77s	training loss:	3.833090
# Done 1940 batches in 224.72s	training loss:	3.832176
# Done 1950 batches in 225.82s	training loss:	3.831122
# Done 1960 batches in 227.23s	training loss:	3.830397
# Done 1970 batches in 228.52s	training loss:	3.829247
# Done 1980 batches in 229.62s	training loss:	3.828634
# Done 1990 batches in 230.77s	training loss:	3.827613
# Done 2000 batches in 231.81s	training loss:	3.826843
# Done 2010 batches in 232.86s	training loss:	3.825917
# Done 2020 batches in 234.08s	training loss:	3.824849
# Done 2030 batches in 235.25s	training loss:	3.823930
# Done 2040 batches in 236.31s	training loss:	3.822667
# Done 7850 batches in 909.47s	training loss:	3.603731
# Done 7860 batches in 910.54s	training loss:	3.603609
# Done 7870 batches in 911.87s	training loss:	3.603477
# Done 7880 batches in 913.32s	training loss:	3.603376
# Done 7890 batches in 914.53s	training loss:	3.603262
# Done 7900 batches in 915.66s	training loss:	3.603116
# Done 7910 batches in 916.66s	training loss:	3.602956
# Done 7920 batches in 917.89s	training loss:	3.602751
# Done 7930 batches in 919.21s	training loss:	3.602543
# Done 7940 batches in 920.31s	training loss:	3.602377
# Done 7950 batches in 921.55s	training loss:	3.602166
# Done 7960 batches in 922.63s	training loss:	3.601916
# Done 7970 batches in 923.65s	training loss:	3.601811
# Done 7980 batches in 924.61s	training loss:	3.601629
# Done 7990 batches in 925.79s	training loss:	3.601449
# Done 8000 batches in 927.48s	training loss:	3.601320
# Done 8010 batches in 928.43s	training loss:	3.601146
# Done 8020 batches in 929.50s	training loss:	3.600975
# Done 8030 batches in 930.87s	training loss:	3.600768
# Done 8040 batches in 932.18s	training loss:	3.600599
# Done 8050 batches in 933.29s	training loss:	3.600414
# Done 8060 batches in 934.38s	training loss:	3.600320
# Done 8070 batches in 935.29s	training loss:	3.600127
# Done 8080 batches in 936.42s	training loss:	3.599936
# Done 8090 batches in 937.37s	training loss:	3.599717
# Done 8100 batches in 938.74s	training loss:	3.599622
# Done 8110 batches in 939.87s	training loss:	3.599433
# Done 8120 batches in 941.01s	training loss:	3.599228
# Done 8130 batches in 942.18s	training loss:	3.599097
# Done 8140 batches in 943.52s	training loss:	3.598908
# Done 8150 batches in 944.55s	training loss:	3.598766
# Done 8160 batches in 945.55s	training loss:	3.598561
# Done 8170 batches in 946.73s	training loss:	3.598338
# Done 8180 batches in 947.96s	training loss:	3.598226
# Done 8190 batches in 948.98s	training loss:	3.598008
# Done 8200 batches in 950.34s	training loss:	3.597904
# Done 8210 batches in 951.58s	training loss:	3.597690
# Done 8220 batches in 952.85s	training loss:	3.597567
# Done 8230 batches in 954.19s	training loss:	3.597422
# Done 8240 batches in 955.39s	training loss:	3.597286
# Done 8250 batches in 956.57s	training loss:	3.597131
# Done 8260 batches in 957.82s	training loss:	3.596991
# Done 8270 batches in 959.14s	training loss:	3.596742
# Done 8280 batches in 960.23s	training loss:	3.596526
# Done 8290 batches in 961.26s	training loss:	3.596324
# Done 8300 batches in 962.37s	training loss:	3.596199
# Done 8310 batches in 963.45s	training loss:	3.596067
# Done 8320 batches in 965.04s	training loss:	3.595889
# Done 8330 batches in 966.15s	training loss:	3.595797
# Done 8340 batches in 967.29s	training loss:	3.595552
# Done 8350 batches in 968.59s	training loss:	3.595366
# Done 8360 batches in 969.86s	training loss:	3.595123
# Done 8370 batches in 970.84s	training loss:	3.594977
# Done 8380 batches in 972.18s	training loss:	3.594736
# Done 8390 batches in 973.35s	training loss:	3.594564
# Done 8400 batches in 974.38s	training loss:	3.594334
# Done 8410 batches in 975.42s	training loss:	3.594149
# Done 8420 batches in 976.59s	training loss:	3.594040
# Done 8430 batches in 977.62s	training loss:	3.593854
# Done 8440 batches in 978.85s	training loss:	3.593654
# Done 8450 batches in 980.21s	training loss:	3.593468
# Done 8460 batches in 981.65s	training loss:	3.593319
# Done 8470 batches in 982.91s	training loss:	3.593180
# Done 8480 batches in 984.11s	training loss:	3.593018
# Done 8490 batches in 984.99s	training loss:	3.592757
# Done 8500 batches in 986.45s	training loss:	3.592617
# Done 8510 batches in 987.57s	training loss:	3.592432
# Done 8520 batches in 988.56s	training loss:	3.592275
# Done 8530 batches in 989.75s	training loss:	3.592152
# Done 8540 batches in 991.17s	training loss:	3.592005
# Done 8550 batches in 992.38s	training loss:	3.591834
# Done 8560 batches in 993.54s	training loss:	3.591638
# Done 8570 batches in 994.67s	training loss:	3.591480
# Done 8580 batches in 995.89s	training loss:	3.591328
# Done 8590 batches in 997.40s	training loss:	3.591173
# Done 8600 batches in 998.89s	training loss:	3.591019
# Done 8610 batches in 1000.12s	training loss:	3.590850
# Done 8620 batches in 1001.27s	training loss:	3.590703
# Done 8630 batches in 1002.34s	training loss:	3.590538
# Done 8640 batches in 1003.53s	training loss:	3.590390
# Done 8650 batches in 1004.78s	training loss:	3.590271
# Done 8660 batches in 1005.94s	training loss:	3.590093
# Done 8670 batches in 1007.38s	training loss:	3.589943
# Done 8680 batches in 1008.53s	training loss:	3.589725
# Done 8690 batches in 1009.74s	training loss:	3.589557
# Done 8700 batches in 1010.86s	training loss:	3.589392
# Done 8710 batches in 1012.18s	training loss:	3.589321
# Done 8720 batches in 1013.34s	training loss:	3.589142
# Done 8730 batches in 1014.37s	training loss:	3.588969
# Done 8740 batches in 1015.38s	training loss:	3.588807
# Done 8750 batches in 1016.59s	training loss:	3.588652
# Done 8760 batches in 1017.68s	training loss:	3.588493
# Done 8770 batches in 1018.77s	training loss:	3.588376
# Done 8780 batches in 1020.21s	training loss:	3.588285
# Done 8790 batches in 1021.35s	training loss:	3.588132
# Done 8800 batches in 1022.45s	training loss:	3.587945
# Done 8810 batches in 1023.63s	training loss:	3.587830
# Done 8820 batches in 1025.32s	training loss:	3.587759
# Done 8830 batches in 1026.32s	training loss:	3.587608
# Done 8840 batches in 1027.43s	training loss:	3.587426
# Done 8850 batches in 1028.45s	training loss:	3.587250
# Done 8860 batches in 1029.96s	training loss:	3.587108
# Done 8870 batches in 1030.94s	training loss:	3.586988
# Done 8880 batches in 1032.17s	training loss:	3.586834
# Done 8890 batches in 1033.19s	training loss:	3.586696
# Done 8900 batches in 1034.25s	training loss:	3.586562
# Done 8910 batches in 1035.33s	training loss:	3.586409
# Done 8920 batches in 1036.50s	training loss:	3.586263
# Done 8930 batches in 1037.82s	training loss:	3.586127
# Done 8940 batches in 1039.09s	training loss:	3.585946
# Done 8950 batches in 1040.22s	training loss:	3.585882
# Done 8960 batches in 1041.37s	training loss:	3.585711
# Done 8970 batches in 1042.57s	training loss:	3.585587
# Done 8980 batches in 1043.58s	training loss:	3.585458
# Done 8990 batches in 1044.81s	training loss:	3.585327
# Done 9000 batches in 1045.89s	training loss:	3.585212
# Done 9010 batches in 1047.08s	training loss:	3.585053
# Done 9020 batches in 1048.25s	training loss:	3.584921
# Done 9030 batches in 1049.48s	training loss:	3.584744
# Done 9040 batches in 1050.71s	training loss:	3.584572
# Done 9050 batches in 1051.76s	training loss:	3.584447
# Done 9060 batches in 1052.88s	training loss:	3.584262
# Done 9070 batches in 1053.99s	training loss:	3.584135
# Done 9080 batches in 1055.23s	training loss:	3.584025
# ...
# Done 16720 batches in 1949.64s	training loss:	3.504799
# Done 16730 batches in 1950.83s	training loss:	3.504740
# Done 16740 batches in 1952.53s	training loss:	3.504672
# Done 16750 batches in 1953.78s	training loss:	3.504609
# Done 16760 batches in 1954.86s	training loss:	3.504525
# Done 16770 batches in 1955.94s	training loss:	3.504458
# Done 16780 batches in 1957.02s	training loss:	3.504414
# Done 16790 batches in 1958.16s	training loss:	3.504322
# Done 16800 batches in 1959.13s	training loss:	3.504247
# Done 16810 batches in 1960.11s	training loss:	3.504167
# Done 16820 batches in 1961.43s	training loss:	3.504114
# Done 16830 batches in 1962.53s	training loss:	3.504092
# Done 16840 batches in 1964.00s	training loss:	3.504038
# Done 16850 batches in 1964.90s	training loss:	3.503978
# Done 16860 batches in 1966.28s	training loss:	3.503917
# Done 16870 batches in 1967.30s	training loss:	3.503847
# Done 16880 batches in 1968.71s	training loss:	3.503796
# Done 16890 batches in 1969.85s	training loss:	3.503709
# Done 16900 batches in 1971.13s	training loss:	3.503651
# Done 16910 batches in 1972.22s	training loss:	3.503571
# Done 16920 batches in 1973.25s	training loss:	3.503488
# Done 16930 batches in 1974.57s	training loss:	3.503423
# Done 16940 batches in 1975.51s	training loss:	3.503341
# Done 16950 batches in 1976.60s	training loss:	3.503231
# Done 16960 batches in 1977.77s	training loss:	3.503163
# Done 16970 batches in 1979.13s	training loss:	3.503115
# Done 16980 batches in 1980.14s	training loss:	3.503030
# Done 16990 batches in 1981.36s	training loss:	3.502958
# Done 17000 batches in 1982.33s	training loss:	3.502873
# Done 17010 batches in 1983.47s	training loss:	3.502814
# Done 17020 batches in 1984.72s	training loss:	3.502765
# Done 17030 batches in 1985.72s	training loss:	3.502676
# Done 17040 batches in 1986.73s	training loss:	3.502601
# Done 17050 batches in 1987.97s	training loss:	3.502517
# Done 17060 batches in 1989.08s	training loss:	3.502440
# Done 17070 batches in 1990.18s	training loss:	3.502368
# Done 17080 batches in 1991.58s	training loss:	3.502296
# Done 17090 batches in 1992.69s	training loss:	3.502215
# Done 17100 batches in 1993.76s	training loss:	3.502138
# Done 17110 batches in 1995.04s	training loss:	3.502072
# Done 17120 batches in 1996.08s	training loss:	3.502011
# Done 17130 batches in 1997.20s	training loss:	3.501957
# Done 17140 batches in 1998.25s	training loss:	3.501895
# Done 17150 batches in 1999.30s	training loss:	3.501816
# Done 17160 batches in 2000.30s	training loss:	3.501763
# Done 17170 batches in 2001.56s	training loss:	3.501705
# Done 17180 batches in 2002.81s	training loss:	3.501652
# Done 17190 batches in 2003.91s	training loss:	3.501582
# Done 17200 batches in 2004.96s	training loss:	3.501515
# Done 17210 batches in 2006.04s	training loss:	3.501434
# Done 17220 batches in 2007.41s	training loss:	3.501362
# Done 17230 batches in 2008.39s	training loss:	3.501311
# Done 17240 batches in 2009.39s	training loss:	3.501244
# Done 17250 batches in 2010.47s	training loss:	3.501193
# Done 17260 batches in 2011.51s	training loss:	3.501096
# Done 17270 batches in 2012.97s	training loss:	3.501067
# Done 17280 batches in 2014.28s	training loss:	3.500975
# Done 17290 batches in 2015.31s	training loss:	3.500894
# Done 17300 batches in 2016.31s	training loss:	3.500818
# Done 17310 batches in 2017.37s	training loss:	3.500768
# Done 17320 batches in 2018.34s	training loss:	3.500721
# Done 17330 batches in 2019.34s	training loss:	3.500668
# Done 17340 batches in 2020.28s	training loss:	3.500599
# Done 17350 batches in 2021.51s	training loss:	3.500569
# Done 17360 batches in 2022.72s	training loss:	3.500514
# Done 17370 batches in 2023.85s	training loss:	3.500469
# Done 17380 batches in 2024.82s	training loss:	3.500387
# Done 17390 batches in 2025.98s	training loss:	3.500300
# Done 17400 batches in 2027.01s	training loss:	3.500192
# Done 17410 batches in 2028.18s	training loss:	3.500126
# Done 17420 batches in 2029.01s	training loss:	3.500063
# Done 17430 batches in 2030.13s	training loss:	3.500022
# Done 17440 batches in 2031.24s	training loss:	3.499956
# Done 17450 batches in 2032.35s	training loss:	3.499904
# Done 17460 batches in 2033.47s	training loss:	3.499826
# Done 17470 batches in 2034.56s	training loss:	3.499777
# Done 17480 batches in 2035.57s	training loss:	3.499732
# Done 17490 batches in 2036.72s	training loss:	3.499657
# Done 17500 batches in 2037.98s	training loss:	3.499563
# Done 17510 batches in 2039.34s	training loss:	3.499472
# Done 17520 batches in 2040.51s	training loss:	3.499385
# Done 17530 batches in 2041.51s	training loss:	3.499282
# Done 17540 batches in 2042.90s	training loss:	3.499232
# Done 17550 batches in 2044.32s	training loss:	3.499190
# Done 17560 batches in 2045.32s	training loss:	3.499141
# Done 17570 batches in 2046.70s	training loss:	3.499072
# Done 17580 batches in 2047.94s	training loss:	3.499019
# Done 17590 batches in 2049.09s	training loss:	3.498941
# Done 17600 batches in 2050.11s	training loss:	3.498869
# Done 17610 batches in 2051.27s	training loss:	3.498778
# Done 17620 batches in 2052.11s	training loss:	3.498738
# Done 17630 batches in 2053.48s	training loss:	3.498651
# Done 17640 batches in 2054.68s	training loss:	3.498604
# Done 17650 batches in 2055.85s	training loss:	3.498561
# Done 17660 batches in 2057.05s	training loss:	3.498482
# Done 17670 batches in 2058.16s	training loss:	3.498397
# Done 17680 batches in 2059.26s	training loss:	3.498313
# Done 17690 batches in 2060.47s	training loss:	3.498251
# Done 17700 batches in 2061.71s	training loss:	3.498212
# Done 17710 batches in 2063.06s	training loss:	3.498168
# Done 17720 batches in 2064.25s	training loss:	3.498109
# Done 17730 batches in 2065.33s	training loss:	3.498029
# Done 17740 batches in 2066.59s	training loss:	3.497957
# Done 17750 batches in 2067.67s	training loss:	3.497898
# Done 17760 batches in 2068.65s	training loss:	3.497848
# Done 17770 batches in 2069.95s	training loss:	3.497781
# Done 17780 batches in 2071.37s	training loss:	3.497727
# Done 17790 batches in 2072.59s	training loss:	3.497695
# Done 17800 batches in 2073.54s	training loss:	3.497608
# Done 17810 batches in 2074.57s	training loss:	3.497502
# Done 17820 batches in 2075.69s	training loss:	3.497426
# Done 17830 batches in 2076.72s	training loss:	3.497347
# Done 17840 batches in 2077.63s	training loss:	3.497287
# Done 17850 batches in 2078.82s	training loss:	3.497236
# Done 17860 batches in 2080.06s	training loss:	3.497131
# Done 17870 batches in 2081.29s	training loss:	3.497073
# Done 17880 batches in 2082.41s	training loss:	3.497002
# Done 17890 batches in 2083.55s	training loss:	3.496947
# Done 17900 batches in 2084.53s	training loss:	3.496880
# Done 17910 batches in 2085.67s	training loss:	3.496813
# Done 17920 batches in 2086.92s	training loss:	3.496772
# Done 17930 batches in 2088.08s	training loss:	3.496697
# Done 17940 batches in 2089.08s	training loss:	3.496636
# Done 17950 batches in 2090.07s	training loss:	3.496562
# Done 17960 batches in 2091.27s	training loss:	3.496493
# Done 17970 batches in 2092.53s	training loss:	3.496453
# Done 17980 batches in 2093.87s	training loss:	3.496373
# Done 17990 batches in 2095.09s	training loss:	3.496269
# Done 18000 batches in 2096.25s	training loss:	3.496196
# Done 18010 batches in 2097.61s	training loss:	3.496131
# Done 18020 batches in 2098.81s	training loss:	3.496049
# Done 18030 batches in 2100.04s	training loss:	3.495975
# Done 18040 batches in 2101.12s	training loss:	3.495917
# Done 18050 batches in 2102.29s	training loss:	3.495875
# Done 18060 batches in 2103.49s	training loss:	3.495809
# Done 18070 batches in 2104.63s	training loss:	3.495725
# Done 18080 batches in 2105.88s	training loss:	3.495641
# Done 18090 batches in 2107.16s	training loss:	3.495592
# Done 18100 batches in 2108.41s	training loss:	3.495550
# Done 18110 batches in 2109.73s	training loss:	3.495491
# Done 18120 batches in 2111.02s	training loss:	3.495448
# Done 18130 batches in 2112.01s	training loss:	3.495395
# Done 18140 batches in 2113.24s	training loss:	3.495327
# Done 18150 batches in 2114.36s	training loss:	3.495255
# Done 18160 batches in 2116.18s	training loss:	3.495208
# Done 18170 batches in 2117.34s	training loss:	3.495110
# Done 18180 batches in 2118.54s	training loss:	3.495057
# Done 18190 batches in 2119.78s	training loss:	3.494979
# Done 18200 batches in 2120.85s	training loss:	3.494903
# Done 18210 batches in 2121.89s	training loss:	3.494826
# Done 18220 batches in 2122.96s	training loss:	3.494745
# Done 18230 batches in 2123.98s	training loss:	3.494703
# Done 18240 batches in 2125.06s	training loss:	3.494639
# Done 18250 batches in 2126.12s	training loss:	3.494560
# Done 18260 batches in 2127.44s	training loss:	3.494456
# Done 18270 batches in 2128.88s	training loss:	3.494367
# Done 18280 batches in 2130.14s	training loss:	3.494303
# Done 18290 batches in 2131.45s	training loss:	3.494246
# Done 18300 batches in 2132.49s	training loss:	3.494157
# Done 18310 batches in 2133.66s	training loss:	3.494081
# Done 18320 batches in 2134.99s	training loss:	3.493993
# Done 18330 batches in 2136.22s	training loss:	3.493940
# Done 18340 batches in 2137.28s	training loss:	3.493863
# Done 18350 batches in 2138.32s	training loss:	3.493775
# Done 18360 batches in 2139.58s	training loss:	3.493728
# Done 18370 batches in 2140.75s	training loss:	3.493657
# Done 18380 batches in 2141.72s	training loss:	3.493590
# Done 18390 batches in 2142.80s	training loss:	3.493543
# Done 18400 batches in 2143.91s	training loss:	3.493479
# Done 18410 batches in 2144.86s	training loss:	3.493455
# Done 18420 batches in 2145.88s	training loss:	3.493356
# Done 18430 batches in 2147.17s	training loss:	3.493298
# Done 18440 batches in 2148.38s	training loss:	3.493225
# Done 18450 batches in 2149.56s	training loss:	3.493180
# Done 18460 batches in 2150.66s	training loss:	3.493129
# Done 18470 batches in 2151.60s	training loss:	3.493052
# Done 18480 batches in 2152.84s	training loss:	3.492981
# Done 18490 batches in 2153.90s	training loss:	3.492906
# Done 18500 batches in 2154.83s	training loss:	3.492852
# Done 18510 batches in 2155.92s	training loss:	3.492768
# Done 18520 batches in 2157.07s	training loss:	3.492677
# Done 18530 batches in 2158.11s	training loss:	3.492612
# Done 18540 batches in 2159.69s	training loss:	3.492575
# Done 18550 batches in 2160.70s	training loss:	3.492514
# Done 18560 batches in 2161.61s	training loss:	3.492429
# Done 18570 batches in 2162.83s	training loss:	3.492357
# Done 18580 batches in 2163.86s	training loss:	3.492322
# Done 18590 batches in 2165.17s	training loss:	3.492267
# Done 18600 batches in 2166.14s	training loss:	3.492204
# Done 18610 batches in 2167.48s	training loss:	3.492125
# Done 18620 batches in 2168.67s	training loss:	3.492054
# Done 18630 batches in 2169.74s	training loss:	3.492028
# Done 18640 batches in 2170.70s	training loss:	3.491947
# Done 18650 batches in 2171.66s	training loss:	3.491851
# Done 18660 batches in 2172.48s	training loss:	3.491786
# Done 18670 batches in 2173.49s	training loss:	3.491706
# Done 18680 batches in 2174.53s	training loss:	3.491625
# Done 18690 batches in 2175.91s	training loss:	3.491596
# Done 18700 batches in 2177.01s	training loss:	3.491536
# Done 18710 batches in 2178.18s	training loss:	3.491474
# Done 18720 batches in 2179.32s	training loss:	3.491410
# Done 18730 batches in 2180.65s	training loss:	3.491348
# Done 18740 batches in 2181.64s	training loss:	3.491296
# Done 18750 batches in 2183.01s	training loss:	3.491242
# Done 18760 batches in 2183.96s	training loss:	3.491171
# Done 18770 batches in 2185.05s	training loss:	3.491111
# Done 18780 batches in 2186.02s	training loss:	3.491044
# Done 18790 batches in 2187.19s	training loss:	3.490965
# Done 18800 batches in 2188.30s	training loss:	3.490902
# Done 18810 batches in 2189.29s	training loss:	3.490836
# Done 18820 batches in 2190.57s	training loss:	3.490802
# Done 18830 batches in 2191.79s	training loss:	3.490738
# Done 18840 batches in 2193.11s	training loss:	3.490690
# Done 18850 batches in 2194.22s	training loss:	3.490638
# Done 18860 batches in 2195.31s	training loss:	3.490588
# Done 18870 batches in 2196.52s	training loss:	3.490544
# Done 18880 batches in 2197.59s	training loss:	3.490485
# Done 18890 batches in 2198.78s	training loss:	3.490403
# Done 18900 batches in 2199.87s	training loss:	3.490330
# Done 18910 batches in 2201.06s	training loss:	3.490261
# Done 18920 batches in 2202.24s	training loss:	3.490217
# Done 18930 batches in 2203.36s	training loss:	3.490165
# Done 18940 batches in 2204.31s	training loss:	3.490121
# Done 18950 batches in 2205.43s	training loss:	3.490068
# Done 18960 batches in 2206.60s	training loss:	3.490013
# Done 18970 batches in 2207.74s	training loss:	3.489950
# Done 18980 batches in 2208.86s	training loss:	3.489869
# Done 18990 batches in 2210.18s	training loss:	3.489816
# Done 19000 batches in 2211.03s	training loss:	3.489774
# Done 19010 batches in 2212.25s	training loss:	3.489706
# Done 19020 batches in 2213.35s	training loss:	3.489629
# Done 19030 batches in 2214.39s	training loss:	3.489560
# Done 19040 batches in 2215.47s	training loss:	3.489527
# Done 19050 batches in 2216.61s	training loss:	3.489466
# Done 19060 batches in 2217.68s	training loss:	3.489406
# Done 19070 batches in 2218.96s	training loss:	3.489395
# Done 19080 batches in 2220.08s	training loss:	3.489338
# Done 19090 batches in 2221.15s	training loss:	3.489258
# Done 19100 batches in 2222.42s	training loss:	3.489223
# Done 19110 batches in 2223.49s	training loss:	3.489176
# Done 19120 batches in 2224.58s	training loss:	3.489110
# Done 19130 batches in 2225.51s	training loss:	3.489026
# Done 19140 batches in 2226.62s	training loss:	3.488968
# Done 19150 batches in 2227.75s	training loss:	3.488914
# Done 19160 batches in 2228.89s	training loss:	3.488860
# Done 19170 batches in 2230.11s	training loss:	3.488784
# Done 19180 batches in 2231.34s	training loss:	3.488734
# Done 19190 batches in 2232.61s	training loss:	3.488665
# Done 19200 batches in 2233.76s	training loss:	3.488595
# Done 19210 batches in 2234.91s	training loss:	3.488537
# Done 19220 batches in 2236.07s	training loss:	3.488485
# Done 19230 batches in 2237.22s	training loss:	3.488402
# Done 19240 batches in 2238.50s	training loss:	3.488328
# Done 19250 batches in 2239.54s	training loss:	3.488264
# Done 19260 batches in 2240.79s	training loss:	3.488191
# Done 19270 batches in 2241.85s	training loss:	3.488151
# Done 19280 batches in 2243.04s	training loss:	3.488081
# Done 19290 batches in 2244.25s	training loss:	3.488018
# Done 19300 batches in 2245.39s	training loss:	3.487941
# Done 19310 batches in 2246.98s	training loss:	3.487852
# Done 19320 batches in 2248.19s	training loss:	3.487813
# Done 19330 batches in 2249.45s	training loss:	3.487752
# Done 19340 batches in 2250.63s	training loss:	3.487681
# Done 19350 batches in 2251.98s	training loss:	3.487620
# Done 19360 batches in 2253.19s	training loss:	3.487575
# Done 19370 batches in 2254.38s	training loss:	3.487527
# Done 19380 batches in 2255.52s	training loss:	3.487462
# Done 19390 batches in 2256.97s	training loss:	3.487417
# Done 19400 batches in 2258.01s	training loss:	3.487377
# Done 19410 batches in 2259.13s	training loss:	3.487320
# Done 19420 batches in 2260.62s	training loss:	3.487244
# Done 19430 batches in 2261.78s	training loss:	3.487176
# Done 19440 batches in 2262.88s	training loss:	3.487105
# Done 19450 batches in 2264.17s	training loss:	3.487046
# Done 19460 batches in 2265.40s	training loss:	3.487018
# Done 19470 batches in 2266.62s	training loss:	3.486946
# Done 19480 batches in 2267.81s	training loss:	3.486863
# Done 19490 batches in 2268.87s	training loss:	3.486820
# Done 19500 batches in 2269.88s	training loss:	3.486766
# Done 19510 batches in 2270.97s	training loss:	3.486688
# Done 19520 batches in 2272.05s	training loss:	3.486661
# Done 19530 batches in 2273.19s	training loss:	3.486580
# Done 19540 batches in 2274.36s	training loss:	3.486539
# Done 19550 batches in 2275.34s	training loss:	3.486477
# Done 19560 batches in 2276.30s	training loss:	3.486416
# Done 19570 batches in 2277.46s	training loss:	3.486368
# Done 19580 batches in 2278.52s	training loss:	3.486341
# Done 19590 batches in 2279.77s	training loss:	3.486291
# Done 19600 batches in 2280.89s	training loss:	3.486254
# Done 19610 batches in 2282.16s	training loss:	3.486197
# 3.486180601246621

# %%
def validate(val_data, batch_size):
    val_err = 0.
    val_batches = 0
    num_validate_words = 0
    start_time = time.time()

    for batch in iterate_minibatches(val_data, batch_size, pad_value):
        inputs, targets, mask = batch

        num_batch_words = mask.sum()
        val_err += val_fn(inputs, targets, mask) * num_batch_words
        val_batches += 1
        num_validate_words += num_batch_words

        if not val_batches % 100:
            print "Done {} batches in {:.2f}s".format(val_batches, time.time() - start_time)

    return val_err / num_validate_words

# %%
validate(valid, 30)
# Out:
# Done 100 batches in 4.54s
# Done 200 batches in 9.34s
# Done 300 batches in 14.35s
# Done 400 batches in 18.75s
# Done 500 batches in 23.27s
# Done 600 batches in 27.62s
# Done 700 batches in 32.04s
# Done 800 batches in 36.39s
# Done 900 batches in 41.09s
# Done 1000 batches in 46.03s
# Done 1100 batches in 50.74s
# Done 1200 batches in 55.62s
# Done 1300 batches in 60.65s
# Done 1400 batches in 65.14s
# Done 1500 batches in 69.61s
# Done 1600 batches in 74.18s
# Done 1700 batches in 78.60s
# Done 1800 batches in 83.59s
# Done 1900 batches in 88.52s
# Done 2000 batches in 92.90s
# Done 2100 batches in 97.71s
# Done 2200 batches in 102.53s
# Done 2300 batches in 107.51s
# Done 2400 batches in 112.12s
# 3.4811877499289308

# %%
def build_context_net(input_var, voc_size, emb_size, lv1_rec_size, lv2_rec_size, context_init, params):
    l_in = L.layers.InputLayer(shape=(1,None), input_var=input_var)
    
    l_emb = L.layers.EmbeddingLayer(l_in,
                                    input_size=voc_size,  # not voc_size+1, because pad_value = <utt_end>
                                    output_size=emb_size)
            
    l_lv1_enc_forw = L.layers.GRULayer(l_emb,
                                       num_units=lv1_rec_size,
                                       grad_clipping=100)
#                                        only_return_final=True)
    
    ###
    
    l_lv1_enc_back = L.layers.GRULayer(l_emb, # backward pass of encoder rnn
                                       num_units=lv1_rec_size,
                                       grad_clipping=100,
#                                        only_return_final=True,
                                       backwards=True)
    
    l2_pooled_forw = L2PoolingLayer(l_lv1_enc_forw)
    l2_pooled_back = L2PoolingLayer(l_lv1_enc_back)

    l_lv1_enc = L.layers.ConcatLayer([l2_pooled_forw, l2_pooled_back]) # concatenation of L2-pooled states
    
    ###    
    
    l_resh = L.layers.ReshapeLayer(l_lv1_enc, shape=(1, 1, 2*lv1_rec_size))
    
    l_lv2_enc = L.layers.GRULayer(l_resh,
                                  num_units=lv2_rec_size,
                                  hid_init=context_init,
                                  grad_clipping=100,
                                  only_return_final=True)

    return l_lv2_enc

# %%
'''
dekoder powinien czytac po jednym slowie, a nie cala sekwencje naraz.
tak jak context_net, bedzie mozna go zainicjowac poprzednim stanem.
'''

def build_decoder_net(input_var, voc_size, emb_size, lv1_rec_size, lv2_rec_size, out_emb_size, 
                      context_init, params):
    l_in = L.layers.InputLayer(shape=(1,None), input_var=input_var)
    
    l_emb = L.layers.EmbeddingLayer(l_in,
                                    input_size=voc_size,  # not voc_size+1, because pad_value = <utt_end>
                                    output_size=emb_size)
    
    l_context_init = L.layers.InputLayer(shape=(1, lv2_rec_size), input_var=context_init)
    
    l_dec_inits = L.layers.DenseLayer(l_context_init,
                                      num_units=lv1_rec_size,
                                      nonlinearity=L.nonlinearities.tanh)
    
    l_dec = L.layers.GRULayer(l_emb,
                              num_units=lv1_rec_size,
                              grad_clipping=100,
                              hid_init=l_dec_inits)
    
    l_resh = L.layers.ReshapeLayer(l_dec, shape=(-1, lv1_rec_size))
    
    l_H0 = L.layers.DenseLayer(l_resh,
                               num_units=out_emb_size,
                               nonlinearity=None)
    
    l_resh2 = L.layers.ReshapeLayer(l_emb, shape=(-1, emb_size))
    
    l_E0 = L.layers.DenseLayer(l_resh2,
                               num_units=out_emb_size,
                               b=None,
                               nonlinearity=None)
    
    l_soft_in = L.layers.ElemwiseSumLayer([l_H0, l_E0])
    
    l_soft = L.layers.DenseLayer(l_soft_in,
                                 num_units=voc_size,
                                 nonlinearity=L.nonlinearities.softmax)
    
    l_out = L.layers.ReshapeLayer(l_soft, shape=(input_var.shape[0], input_var.shape[1], voc_size))

    return l_out

# %%
input_var = T.imatrix('inputs')
context_init = T.matrix('context_init')

context_net = build_context_net(input_var, voc_size, emb_size, lv1_rec_size, lv2_rec_size, 
                                context_init, params=None)

context_out = L.layers.get_output(context_net, deterministic=True)

dec_net = build_decoder_net(input_var, voc_size, emb_size, lv1_rec_size, lv2_rec_size, out_emb_size, 
                            context_init, params=None)

dec_out = L.layers.get_output(dec_net, deterministic=True)

print 'Compiling theano functions...'

get_probs = theano.function([input_var, context_init], dec_out)

get_context_output = theano.function([input_var, context_init], context_out)

# %%
con_init = np.zeros((1, lv2_rec_size), dtype=np.float32)

# %%
get_probs(np.array(train[0]).astype(np.int32)[np.newaxis, :], con_init).argmax(axis=2)

# %%
con_init = get_context_output(np.array(train[0]).astype(np.int32)[np.newaxis, :], con_init)
con_init
